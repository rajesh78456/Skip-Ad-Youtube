# %%
import pyautogui
print("pyautogui is working")
# Out:
# pyautogui is working

# %%
import pyautogui
import collections
import time

skip_ad_wait_time = 0.5  # seconds

CURSOR_LOC_FINDER = 1
TEST = (CURSOR_LOC_FINDER == 0)

for i in range(20):
    time.sleep(skip_ad_wait_time)

    if CURSOR_LOC_FINDER == 1:
        skip_button_location = pyautogui.position()
        print(f"The current cursor position is: {skip_button_location}")

    if TEST:
        Point = collections.namedtuple("Point", "x y")
        skip_button_location = Point(x=483, y=507)
        print(f"Skipping ad at: {skip_button_location}")
        time.sleep(skip_ad_wait_time)
        pyautogui.click(skip_button_location)
# Out:
# The current cursor position is: Point(x=915, y=355)
# The current cursor position is: Point(x=915, y=355)
# The current cursor position is: Point(x=726, y=720)
# The current cursor position is: Point(x=726, y=720)
# The current cursor position is: Point(x=1278, y=628)
# The current cursor position is: Point(x=1529, y=508)
# The current cursor position is: Point(x=1655, y=780)
# The current cursor position is: Point(x=1734, y=860)
# The current cursor position is: Point(x=1804, y=894)
# The current cursor position is: Point(x=1819, y=900)
# The current cursor position is: Point(x=1818, y=903)
# The current cursor position is: Point(x=1833, y=908)
# The current cursor position is: Point(x=1827, y=909)
# The current cursor position is: Point(x=1827, y=909)
# The current cursor position is: Point(x=1827, y=909)
# The current cursor position is: Point(x=1827, y=909)
# The current cursor position is: Point(x=1729, y=837)
# The current cursor position is: Point(x=287, y=391)
# The current cursor position is: Point(x=191, y=358)
# The current cursor position is: Point(x=191, y=358)
